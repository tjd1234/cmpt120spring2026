# %% [markdown]
# # Homework 1

# %% [markdown]
# This is based on chapter 1 of the course notes, and covers a few topics not
# mentioned there.
#
# You can also do the exercises at the bottom on the textbook chapter.

# %% [markdown]
# ## Escape Characters
#
# In a string, a '`\`' indicates an **escape character**, which means that the
# next character is special in some way. For example, `'\n` is the escape
# character called **newline**. It represents a command to send the cursor to the
# next line. For example:

# %%
print('one\ntwo\n\nthree!')
print()
print(4 * (5 * '*' + '\n'))
# Out:
# one
# two
#
# three!
#
# *****
# *****
# *****
# *****

# %% [markdown]
# To print a `\` character, you need to use `\\`:

# %%
print('\\n is newline')
# Out:
# \n is newline

# %% [markdown]
# You can use `\'` and `\"` to print single and double quotes:

# %%
print('It\'s \"par tea time!\"')
# Out:
# It's "par tea time!"

# %% [markdown]
# Be careful when calculating the length of a string that contains escape
# characters. The length of the string `'\n'` is 1, not 2:

# %%
print(len('\n\n\n'))
# Out:
# 3

# %% [markdown]
# Here are the most common escape characters in Python strings:
#
# |    |   **name**   |                                     **common use**                                    | **example**                            |
# |:--:|:------------:|:-------------------------------------------------------------------------------------:|----------------------------------------|
# | \n |    newline   | blank line                                                                            | >>> print('a\nb')<br>a<br>b            |
# | \t |      tab     | fixed-width space, for formatting;<br>width of a tab is **not** defined by <br>Python | print('\thello!')<br>    hello!    |
# | \\\ |   backslash  | \ as a literal character                                                              | print('root\\\\users')<br>root\users |
# | \\' | single quote | ' as a literal character                                                           | print('\\'-quote')<br>'-quote       |
# | \\" | double quote | " as a literal character                                                           | print("\\"-quote")<br>"-quote       |

# %% [markdown]
# ## Whitespace
#
# A **whitespace** character is a space `' '`, tab `\t`, or newline `\n`, i.e.
# characters that don't print anything, and so look like white spaces on paper.
# **Whitespace** refers to a string of whitespace characters.
#
# For example, the string `'  \t\n'` contains three whitespace characters has
# length 3. If you print it, you will see nothing:

# %%
print(len('  \t\n'))  # 3
print('  \t\n')
print('the space above this was made by three whitespace characters')
# Out:
# 4
#
#
# the space above this is three whitespace characters

# %% [markdown]
# ## Preventing newline at the end of a print statement

# %% [markdown]
# `print` automatically adds a newline character at the end of the output. If you
# don't want this to happen, you can use the `end` parameter:

# %%
print('line 1 ', end='')
print('line 2 ', end='')
print('line 3')
print('line 4')
# Out:
# line 1 line 2 line 3
# line 4

# %% [markdown]
# ## Practice Question 1

# %% [markdown]
# Write a single Python `print` statement that prints exactly this on the screen:
#
# ```
# \n \t \\ \' \" are escape characters
# ```

# %% [markdown]
# ## Sample Solution to Question 1

# %%
print('\\n \\t \\\\ \\\' \\\" are escape characters')
# Out:
# \n \t \\ \' \" are escape characters

# %% [markdown]
# ## Practice Question 2
#
# Use one or more print statements to print this:
#
# ```
# \    /
#  \  /
#   \/
#   /\
#  /  \
# /    \
# ```
#
# Try to do it with as few print statements as possible.

# %% [markdown]
# ## Sample Solution to Question 2

# %%
print('\\    /')
print(' \\  /')
print('  \\/')
print('  /\\')
print(' /  \\')
print('/    \\')
# Out:
# \    /
#  \  /
#   \/
#   /\
#  /  \
# /    \

# %% [markdown]
# Here's how to do it with a single print statement:

# %%
print('\\    /\n \\  /\n  \\/\n  /\\\n /  \\\n/    \\')
# Out:
# \    /
#  \  /
#   \/
#   /\
#  /  \
# /    \

# %% [markdown]
# ## Practice Question 3
#
# Write a program that asks the user for some informations and prints a web page
# that you can view in your web browser. This is known as **static web page
# generation**, and is a common way to make web pages that are not changed after
# they are created.
#
# We want the program's output to look like this:
#
# ```html
# <html>
# <head>
# <title>Anita's Web Page</title>
# </head>
#
# <body>
# <h1>Anita's Web Page</h1>
#
# <p>Welcome to my web page. I'm Anita, a student at SFU. Here are a few of my favourite things:</p>
#
# <ul>
# <li>Programming</li>
# <li>Bowling</li>
# <li>Traveling</li>
# </ul>
#
# </body>
# </html>
# ```
#
# Write a program that reads a person's name (e.g. "Anita"), asks them for three
# of their favourite things, and then generates a web page with that information
# as shown. If you paste the output in a file called `webpage.html`, you can view
# it in your web browser.

# %% [markdown]
# ## Sample Solution to Question 3: Method 1
#
# This solution prints the web page using one `print` per line. Note that some of
# the strings are f-strings.

# %%
# get the information
name = 'Anita'
thing1 = 'Programming'
thing2 = 'Bowling'
thing3 = 'Traveling'

# generate the web page
print("<html>")
print("<head>")
print(f"<title>{name}'s Web Page</title>")
print("</head>")
print("<body>")
print(f"<h1>{name}'s Web Page</h1>")
print(f"<p>Welcome to my web page. I'm {name}, a student at SFU. Here are a few of my favourite things:</p>")
print("<ul>")
print(f"<li>{thing1}</li>")
print(f"<li>{thing2}</li>")
print(f"<li>{thing3}</li>")
print("</ul>")
print("</body>")
print("</html>")
# Out:
# <html>
# <head>
# <title>Anita's Web Page</title>
# </head>
# <body>
# <h1>Anita's Web Page</h1>
# <p>Welcome to my web page. I'm Anita, a student at SFU. Here are a few of my favourite things:</p>
# <ul>
# <li>Programming</li>
# <li>Bowling</li>
# <li>Traveling</li>
# </ul>
# </body>
# </html>

# %% [markdown]
# ## Sample Solution to Question 3: Method 2
#
# This solution prints the web page using a single triple-quoted f-string.

# %%
# get the information
name = 'Anita'
thing1 = 'Programming'
thing2 = 'Bowling'
thing3 = 'Traveling'

# generate the web page
print(f"""<html>
<head>
<title>{name}'s Web Page</title>
</head>

<body>
<h1>{name}'s Web Page</h1>

<p>Welcome to my web page. I'm {name}, a student at SFU. Here are a few of my favourite things:</p>

<ul>
<li>{thing1}</li>
<li>{thing2}</li>
<li>{thing3}</li>
</ul>

</body>
</html>""")
# Out:
# <html>
# <head>
# <title>Anita's Web Page</title>
# </head>
#
# <body>
# <h1>Anita's Web Page</h1>
#
# <p>Welcome to my web page. I'm Anita, a student at SFU. Here are a few of my favourite things:</p>
#
# <ul>
# <li>Programming</li>
# <li>Bowling</li>
# <li>Traveling</li>
# </ul>
#
# </body>
# </html>
