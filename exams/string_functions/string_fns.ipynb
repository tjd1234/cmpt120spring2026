# %% [markdown]
# # String Functions
#
# The following functions are similar to the string dot-functions built-in to
# Python strings.
#
# Implement each them using basic Python features. Don't use any string
# dot-functions unless the question specifically allows it.

# %% [markdown]
# ## Capitalize
#
# `capitalize(s)` returns a new string the same as `s` but with the first
# character capitalized. If the first character is not a letter, `s` is returned
# unchanged.
#
# Use `.isalpha()` to check if a character is a letter, e.g.:
#
# ```python
# s = "h"
# print(s.isalpha())  # True
#
# s = "A"
# print(s.isalpha())  # True
# s = "!"
# print(s.isalpha())  # False
# ```
#
# Use `s.upper()` to convert a string to uppercase, e.g.:
#
# ```python
# s = "hello"
# print(s.upper())  # HELLO
#
# s = "t"
# print(s.upper())  # T
#
# s = "123"
# print(s.upper())  # 123
# ```

# %%
def capitalize(s):
    pass # ... your function here ...

print(capitalize("hello"))  # "Hello"
print(capitalize("world"))  # "World"
print(capitalize("123"))    # "123"
print(capitalize(""))       # ""
# Out:
# Hello
# World
# 123

# %% [markdown]
# ## count_char
#
# `count_char(s, char)` returns the number of times `char` appears in `s`. Assume
# `s` is a string (any string!), and `char` is a single character, i.e. a string
# of length 1.

# %%
def count_char(s, char):
    pass # ... your function here ...

print(count_char("hello", "l"))  # 2
print(count_char("hello", "o"))  # 1
print(count_char("hello", "x"))  # 0
# Out:
# 2
# 1
# 0

# %% [markdown]
# ## ends_with
#
# `ends_with(s, suffix)` returns `True` if `s` ends with `suffix`, and `False`
# Assume both `s` and `suffix` are non-empty strings.

# %%
def ends_with(s, suffix):
    pass # ... your function here ...

print(ends_with("hello", "o"))          # True
print(ends_with("hello", "lo"))         # True
print(ends_with("hello", "hello"))      # True
print(ends_with("goodbye", "good"))     # False
print(ends_with("goodbye", "goodbye!")) # False
# Out:
# True
# True
# True
# False
# False

# %% [markdown]
# ## starts_with
#
# `starts_with(s, prefix)` returns `True` if `s` starts with `prefix`, and `False` otherwise.
# Assume both `s` and `prefix` are non-empty strings.

# %%
def starts_with(s, prefix):
    pass # ... your function here ...

print(starts_with("mouse", "m"))          # True
print(starts_with("mouse", "mou"))        # True
print(starts_with("mouse", "mouse"))      # True
print(starts_with("feather", "F"))        # False
print(starts_with("feather", "feather!")) # False

def starts_with(s, prefix):
    return s[:len(prefix)] == prefix
# Out:
# True
# True
# True
# False
# False

# %% [markdown]
# ## expand_tabs
#
# `expand_tabs(s, tabsize)` returns a new string that is the same as `s` but with
# each tab character, `\t`, replaced by `width` `*` characters. Assume `tabsize`
# is greater than, or equal to, 0.
#
# Do *not* use the `replace` in your implementation.

# %%
def expand_tabs(s, tabsize):
    pass # ... your function here ...

print(expand_tabs('a\tb\tc', 3)) # "a***b***c"
print(expand_tabs('\t\t\t', 1))  # "***"
print(expand_tabs('a\tb\tc', 0)) # "abc"
print(expand_tabs('Cat', 4))     # "Cat"
# Out:
# a***b***c
# ***
# abc
# Cat

# %% [markdown]
# ## find_char
#
# `find_char(s, char)` returns the index of the first occurrence of `char` in `s`.
# If `char` is not found, `-1` is returned. Assume `s` is any string, and `char`
# is a single character, i.e. a string of length 1.

# %%
def find_char(s, char):
    pass # ... your function here ...

print(find_char("hello", "e"))  # 1
print(find_char("hello", "e"))  # 2 (not 3!)
print(find_char("hello", "x"))  # -1
# Out:
# 1
# 1
# -1

# %% [markdown]
# ## is_digit_char
#
# `is_digit_char(s)` returns `True` if `s` is one of the digits `'0'`, `'1'`,
# `'2'`, ..., `'9'`, and `False` otherwise. Assume `s` is a string.

# %%
def is_digit_char(s):
    pass # ... your function here ...

print(is_digit_char('0'))  # True
print(is_digit_char('9'))  # True
print(is_digit_char('a'))  # False
print(is_digit_char('19')) # False
# Out:
# True
# True
# False
# False

# %% [markdown]
# ## left_strip
#
# `left_strip(s)` returns a new string that is the same as string `s` but with all
# leading spaces and tabs removed. Spaces and tabs not at the beginning are kept
# as-is.
#
# **Hint**: Find the first character that is not a space or tab, and return the
# substring starting at that character.

# %%
def left_strip(s):
    pass # ... your function here ...

print("'" + left_strip("  \tHi Bo!") + "'")  # 'Hi Bo!'
print("'" + left_strip("  Hi Bo! \t") + "'") # 'Hi Bo! 	'
print("'" + left_strip("Hi Bo!") + "'")      # 'Hi Bo!'

# %% [markdown]
# ## right_strip
#
# `right_strip(s)` returns a new string that is the same as string `s` but with
# all trailing spaces and tabs removed. Spaces and tabs not at the end are kept
# as-is.
#
# **Hint 1**: One way to implement this is to find the right-most character that
# is not a space or tab, and return the substring up to, and including, that
# character.
#
# **Hint 2**: A different way to implement this is in one line using `left_strip`.

# %%
def right_strip(s):
    pass # ... your function here ...

print("'" + right_strip("Hi Bo!  \t") + "'")  # 'Hi Bo!'
print("'" + right_strip("  Hi Bo! \t") + "'") # '  Hi Bo!'
print("'" + right_strip("Hi Bo!") + "'")      # 'Hi Bo!'
# Out:
# 'Hi Bo!'
# '  Hi Bo!'
# 'Hi Bo!'

# %% [markdown]
# ## strip
#
# `strip(s)` returns a new string that is the same as `s` but with all leading and
# trailing spaces and tabs removed.
#
# **Hint**: You can use `left_strip` and `right_strip` to implement this in one line.

# %%
def strip(s):
    pass # ... your function here ...

print("'" + strip("  \tHi Bo!") + "'")  # 'Hi Bo!'
print("'" + strip("  Hi Bo! \t") + "'") # 'Hi Bo!'
print("'" + strip("Hi Bo!") + "'")      # 'Hi Bo!'
# Out:
# 'Hi Bo!'
# 'Hi Bo!'
# 'Hi Bo!'

# %% [markdown]
# ## replace_char
#
# `replace_char(s, old, new)` returns a new string that is the same as `s` but
# with all occurrences of `old` replaced with `new`. Assume `s` is any string, and
# `old` and `new` are strings of length 1.
#
# Don't use the `replace` method in your implementation.

# %%
def replace_char(s, old, new):
    pass # ... your function here ...

print(replace_char('hello', 'e', 'a'))   # hallo
print(replace_char('What???', '?', '!')) # What!!!
print(replace_char('Hello', 'l', '1'))   # He11o
# Out:
# hallo
# What!!!
# Herro

# %% [markdown]
# ## left_zfill
#
# `left_zfill(s, width)` returns a new string that is the same as `s` but with
# leading zeros added at the beginning to make it `width` characters long. Assume
# `s` is any string, and `width` is greater than, or equal to, 0. If `s` is
# already `width` or more characters long, return it unchanged.
#
# *Don't* use strings methods like `zfill` or `rjust` in your implementation.

# %%
def left_zfill(s, width):
    pass # ... your function here ...

print(left_zfill('123', 5))  # 00123
print(left_zfill('dog', 3))  # dog
print(left_zfill('cats', 7)) # 000cat

# %% [markdown]
# ## right_zfill

# %% [markdown]
# `right_zfill(s, width)` returns a new string that is the same as `s` but with
# trailing zeros added at the end to make it `width` characters long. Assume
# `s` is any string, and `width` is greater than, or equal to, 0. If `s` is
# already `width` or more characters long, return it unchanged.
#
# *Don't* use strings methods like `zfill` or `ljust` in your implementation.

# %%
def right_zfill(s, width):
    pass # ... your function here ...

print(right_zfill('123', 5))  # 12300
print(right_zfill('dog', 3))  # dog
print(right_zfill('cat', 7))  # cat0000
# Out:
# 12300
# dog
# cat0000
